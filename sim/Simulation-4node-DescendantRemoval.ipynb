# %%
import configparser
import random
import numpy as np
import tensorflow as tf
from sklearn.metrics import roc_auc_score, average_precision_score
from keras.models import load_model
from keras.callbacks import LearningRateScheduler, ModelCheckpoint, Callback
from keras.applications.inception_resnet_v2 import InceptionResNetV2
from keras.models import load_model, Model
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, BatchNormalization, \
                        Input, Dense, GlobalAveragePooling2D, Dropout
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
from keras import optimizers
from keras.utils import to_categorical
from collections import Counter
import keras.optimizers
from keras.callbacks import Callback
from keras.callbacks import EarlyStopping
from keras.utils import plot_model
import glob, os
import tensorflow as tf
import pandas as pd
from random import shuffle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
from sklearn.metrics import roc_auc_score, average_precision_score, mean_absolute_error, accuracy_score
from sklearn.model_selection import StratifiedKFold
from sklearn.linear_model import LogisticRegression, Perceptron
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import GaussianNB, BernoulliNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, AdaBoostClassifier, BaggingClassifier, GradientBoostingClassifier
from sklearn.neural_network import MLPClassifier
import pandas as pd
from pycausal import search as s
from pycausal.pycausal import pycausal as pc
from collections import defaultdict
from numpy.polynomial.polynomial import polyfit  
from scipy.stats import pearsonr
from pylab import text
from pycausal import prior as p
import itertools

# select your GPU Here
os.environ["CUDA_VISIBLE_DEVICES"]="" #Comment this line out if you want all GPUS (2 hehe)

# python full-display web browser
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))


def get_model(dense, dropouts, inputs):
    # dense is an ordered list of the number of dense neurons like [1024, 2048, 1024]
    # dropouts is an ordered list of the dropout masks like [0.2, 0.3, 0.4]
    inputs = keras.Input(shape = (inputs,))
    x = keras.layers.Dense(dense[0], activation = 'relu')(inputs)
    x = keras.layers.Dropout(dropouts[0])(x, training=False)
    for den, drop in zip(dense[1:], dropouts[1:]):
        x = keras.layers.Dense(den, activation = 'relu')(x)
        x = keras.layers.Dropout(drop)(x, training=False)
    outputs = keras.layers.Dense(1, activation = 'linear')(x)
    model = keras.Model(inputs, outputs)
    return model

def get_bic(df, prior, penalty = 2):

    tetrad.run(algoId = 'gfci', dfs = df, testId= 'sem-bic', scoreId = 'sem-bic', dataType = 'continuous',
               structurePrior = 1.0, samplePrior = 1, maxDegree = -1, maxPathLength = -1, priorKnowledge = prior,
               completeRuleSetUsed = False, faithfulnessAssumed = True, verbose = True, penalty = 200
               )
    
    BIC = tetrad.getTetradGraph().getAllAttributes().toString()
    BIC = float(BIC.split('=')[-1].split('}')[0])
    return BIC #/ len(df)


def normalize(a):
    return (a - np.min(a)) / (np.max(a) - np.min(a))
def make_categorical(df, complete_df, categoricals):   
    retval = None
    for key in df.columns:
        if retval is not None:
            if key in categoricals:
                retval = np.concatenate((retval, to_categorical(df[key], len(complete_df[key].unique()))), axis = 1)
            else:
                retval = np.concatenate((retval, df[key].values[...,np.newaxis]), axis = 1)
        else:
            if key in categoricals:
                retval = to_categorical(df[key], len(complete_df[key].unique()))
            else:
                retval = df[key]
    return retval
num_models = 100   
pc = pc()
pc.start_vm(java_max_heap_size = '11000M')
tetrad = s.tetradrunner()

models = []
model_names = []



randomize = False
if randomize:
    layers = [256, 512, 1024, 2048, 4096]
    for i in range(num_models):
        network = []
        for j in range(3):
            network.append(layers[random.randint(0,len(layers) -1)])
        models.append(network)
        model_names.append('temp/sim' + str(i))
    print(models, model_names)    
else:
    model_layers = [512, 256]
    for i in range(num_models):
        models.append(model_layers)
        model_names.append('temp/sim' + str(i))

print(models, model_names)
# Out:
# /home/tkyono/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# /home/tkyono/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# <style>.container { width:100% !important; }</style>
# [[512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256]] ['temp/sim0', 'temp/sim1', 'temp/sim2', 'temp/sim3', 'temp/sim4', 'temp/sim5', 'temp/sim6', 'temp/sim7', 'temp/sim8', 'temp/sim9', 'temp/sim10', 'temp/sim11', 'temp/sim12', 'temp/sim13', 'temp/sim14', 'temp/sim15', 'temp/sim16', 'temp/sim17', 'temp/sim18', 'temp/sim19', 'temp/sim20', 'temp/sim21', 'temp/sim22', 'temp/sim23', 'temp/sim24', 'temp/sim25', 'temp/sim26', 'temp/sim27', 'temp/sim28', 'temp/sim29', 'temp/sim30', 'temp/sim31', 'temp/sim32', 'temp/sim33', 'temp/sim34', 'temp/sim35', 'temp/sim36', 'temp/sim37', 'temp/sim38', 'temp/sim39', 'temp/sim40', 'temp/sim41', 'temp/sim42', 'temp/sim43', 'temp/sim44', 'temp/sim45', 'temp/sim46', 'temp/sim47', 'temp/sim48', 'temp/sim49', 'temp/sim50', 'temp/sim51', 'temp/sim52', 'temp/sim53', 'temp/sim54', 'temp/sim55', 'temp/sim56', 'temp/sim57', 'temp/sim58', 'temp/sim59', 'temp/sim60', 'temp/sim61', 'temp/sim62', 'temp/sim63', 'temp/sim64', 'temp/sim65', 'temp/sim66', 'temp/sim67', 'temp/sim68', 'temp/sim69', 'temp/sim70', 'temp/sim71', 'temp/sim72', 'temp/sim73', 'temp/sim74', 'temp/sim75', 'temp/sim76', 'temp/sim77', 'temp/sim78', 'temp/sim79', 'temp/sim80', 'temp/sim81', 'temp/sim82', 'temp/sim83', 'temp/sim84', 'temp/sim85', 'temp/sim86', 'temp/sim87', 'temp/sim88', 'temp/sim89', 'temp/sim90', 'temp/sim91', 'temp/sim92', 'temp/sim93', 'temp/sim94', 'temp/sim95', 'temp/sim96', 'temp/sim97', 'temp/sim98', 'temp/sim99']

# %%
import networkx as nx

def random_dag(nodes, edges):
    """Generate a random Directed Acyclic Graph (DAG) with a given number of nodes and edges."""
    G = nx.DiGraph()
    for i in range(nodes):
        G.add_node(i)
    while edges > 0:
        a = random.randint(0,nodes-1)
        b=a
        while b==a:
            b = random.randint(0,nodes-1)
        G.add_edge(a,b)
        if nx.is_directed_acyclic_graph(G):
            edges -= 1
        else:
            # we closed a loop!
            G.remove_edge(a,b)
    return G

# %%
import pydot
from IPython.display import SVG

def examine_graph_continuous(df, prior = None):
    tetrad.run(algoId = 'fges', dfs = df,  scoreId = 'sem-bic', dataType = 'continuous',
               structurePrior = 1.0, samplePrior = 1, maxDegree = -1, maxPathLength = -1, priorKnowledge = prior,
               completeRuleSetUsed = False, faithfulnessAssumed = True, verbose = True,
               )
    return tetrad.getTetradGraph()

def gen_data(list_vertex = [], list_edges = [], mean = 0, var = 1, SIZE = 20000):
    g = []
    for v in list_vertex:
        g.append(np.random.normal(mean,var,SIZE))
        
    for edge in list_edges:
        g[edge[1]] += g[edge[0]]
    g = np.swapaxes(g,0,1)
    return pd.DataFrame(g, columns = list(map(str, list_vertex)))

# %%
bestMSE = []
bestBIC = []
bestCOMBO = []
averageDegree = []
targetDegree = []
target_inD = []
target_outD = []
descendants = []
t= 0
while (t < 30):
    train_size = 20000
    nodes = 4
    test_mean = 1
    test_var = 2
    test_size = 2000
    
    G = random_dag(nodes, random.randint(nodes, nodes*nodes)) # since max number of edges is n^2
    df = gen_data(np.arange(nodes), G.edges, SIZE = train_size)
    require = []
    for i in G.edges:
        require.append([str(i[0]), str(i[1])])  
    prior = p.knowledge(requiredirect = require)
    examine_graph_continuous(df, prior)
    
    # Check to make sure that graph matches our prior knowledge. Or else abort this test.
    a = set()
    for i in tetrad.getEdges():
        a.add((i[0], i[-1]))
    b = set()
    for i in require:
        b.add((i[0], i[1]))
    print("A = ", a)
    print("B = ", b)
    if a != b:
        continue
        
    known_conx = set({})
    for i in tetrad.getEdges():
        if ' --> ' in i:
            known_conx.add((i.split(' --> ')[0], i.split(' --> ')[1]))
    known_conx
        
    # Need to set our inputs and outputs
    inputs = set(np.arange(nodes))
    target = str(a.pop()[random.randint(0,1)])
    inputs.remove(int(target))
    inputs = list(map(str, inputs))
    df_test = gen_data(np.arange(nodes), G.edges, mean = test_mean, var = test_var, SIZE = test_size)
    target = [target]
    
    print("Inputs = ", inputs)
    print("Target = ", target)
    
    descend = nx.descendants(G, int(target[0]))
    print("Descendents = ", descend)
        
    
    # now let's remove them. from the DAG.
    print("Removing descendants")
    print("Required before", require)
    for d in descend:
        for r in require.copy():
            if str(d) in r:
                print("Removing", r)
                require.remove(r)
    
    print("Required After:", require)
    # update our prior....
    prior = p.knowledge(requiredirect = require)
    
    #df.drop(df_test.index, inplace = True)
    #df_test.reset_index(inplace = True)
    #df.sample(frac= 1).reset_index(inplace = True) # this will shuffle and reset index

    x_test = df_test[inputs]
    y_test = df_test[target]

    causal_split = 0.2
    val_split = 0.2
    train_split = 1 - (causal_split + val_split)

    x_causal = df[inputs][-int(causal_split * len(df)) :]
    y_causal = df[target][-int(causal_split * len(df)) :]

    x_val = df[inputs][int(train_split * len(df)):-int(causal_split * len(df))]
    y_val = df[target][int(train_split * len(df)):-int(causal_split * len(df))]

    x_train = df[inputs][:int(train_split * len(df))]
    y_train = df[target][:int(train_split * len(df))]

    verbosity = 0

    for idx, model_name in enumerate(model_names):
        if type(models[idx]) is list:
            #clear session
            keras.backend.clear_session() 
            #get model according to specification
            model = get_model(models[idx], [0.2] * len(models), np.shape(x_train)[1])
            callbacks = [ModelCheckpoint(model_name, verbose= verbosity, monitor='val_loss',save_best_only=True), 
                         EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=2, verbose= verbosity, mode='auto')]
            model.compile(optimizer = optimizers.SGD(lr = 0.0001, momentum = 0.9, ), loss='mean_squared_error', metrics = ['mse'])
            #print(len(X), len(y))
            model.fit(x_train, y_train, epochs = 20, validation_data = (x_val, y_val), callbacks = callbacks, batch_size = 32, verbose = verbosity)
        else:
            models[idx].fit(X,y)





    generalization = []
    metrics = []
    proposed = []
    x_causal.reset_index(drop=True, inplace = True)
    for idx, model_name in enumerate(model_names):
        #print(model_name)
        if type(models[idx]) is list:
            keras.backend.clear_session()
            model = load_model(model_name)
        else:
            model = models[idx]

        y_pred = model.predict(x_test)
        generalization.append(mean_absolute_error(y_pred, y_test))

        #### CHECK FOR CAUSAL METRIC HERE
        y_causal_pred = model.predict(x_causal)
        causal_targets = pd.DataFrame(y_causal_pred, columns = target)
        
        #causal_targets.reset_index(drop=True, inplace = True)
        causal_df = x_causal.join(causal_targets)
        print("Dropping", list(map(str, descend)), causal_df.columns)
        causal_df.drop(columns = list(map(str, descend)), inplace = True)

        print("Causal_df ", causal_df.columns)

        metrics.append(mean_absolute_error(y_causal_pred, y_causal))
        #print(x_causal.head)
        bic_pred = get_bic(causal_df, prior)
        #print(bic_pred, tetrad.getEdges())

        
        proposed.append(bic_pred)
        print(bic_pred, tetrad.getEdges())   
            #metrics = metrics[:-1]
            #generalization = generalization[:-1]
    nbest = 10
    print(proposed)
    total = normalize(metrics) + normalize(proposed)
    final = pd.DataFrame(np.stack((metrics, proposed, total, generalization), axis = 1), columns = ['metrics', 'proposed', 'combined', 'generalization'])
    print("MSE = ", np.sum(final.nsmallest(nbest, 'metrics')['generalization'].values))
    print("BIC = ", np.sum(final.nsmallest(nbest, 'proposed')['generalization'].values))
    print("COMB = ",np.sum(final.nsmallest(nbest, 'combined')['generalization'].values))
    bestMSE.append(final.nsmallest(nbest, 'metrics')['generalization'].values)
    bestBIC.append(final.nsmallest(nbest, 'proposed')['generalization'].values)
    bestCOMBO.append(final.nsmallest(nbest, 'combined')['generalization'].values)
    print("Times = ", t)
    d = []
    for i in G.degree():
        d.append(i[1])
        if str(i[0]) in target:
            targetDegree.append(i[1])
    averageDegree.append(np.mean(d))
    target_inD.append(G.in_degree(int(target[0])))
    target_outD.append(G.out_degree(int(target[0])))
    descendants.append(len(nx.descendants(G, int(target[0]))))
    print(targetDegree, averageDegree)
    t += 1
    
np.mean(bestMSE), np.mean(bestCOMBO), np.std(bestMSE), np.std(bestCOMBO)
# Out:
# A =  {('2', '3'), ('0', '1'), ('1', '3'), ('2', '1'), ('0', '3')}
# B =  {('0', '1'), ('0', '3'), ('2', '1'), ('1', '3')}
# A =  {('3', '0'), ('1', '2'), ('1', '0'), ('3', '2'), ('2', '0'), ('3', '1')}
# B =  {('1', '2'), ('1', '0'), ('3', '2'), ('2', '0'), ('3', '1')}
# A =  {('0', '1'), ('2', '3'), ('1', '3'), ('2', '1'), ('0', '3'), ('0', '2')}
# B =  {('0', '1'), ('1', '3'), ('2', '1'), ('0', '3'), ('0', '2')}
# A =  {('1', '2'), ('1', '0'), ('3', '2'), ('1', '3'), ('0', '3'), ('0', '2')}
# B =  {('1', '0'), ('0', '3'), ('3', '2'), ('0', '2')}
# A =  {('3', '0'), ('0', '1'), ('0', '2'), ('3', '2'), ('2', '1'), ('3', '1')}
# B =  {('3', '0'), ('3', '1'), ('3', '2'), ('0', '1'), ('2', '1'), ('0', '2')}
# Inputs =  ['1', '2', '3']
# Target =  ['0']
# Descendents =  {1, 2}
# Removing descendants
# Required before [['0', '1'], ['0', '2'], ['2', '1'], ['3', '0'], ['3', '2'], ['3', '1']]
# Removing ['0', '1']
# Removing ['2', '1']
# Removing ['3', '1']
# Removing ['0', '2']
# Removing ['3', '2']
# Required After: [['3', '0']]
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2116.537012960976 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2206.6666983912496 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2217.1988636272845 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2123.6628945979937 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2112.5817920565382 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2055.278761128523 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2200.150879952074 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2102.5424026767396 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2162.448822213287 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2183.020834662385 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2204.474732171035 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2110.9550069544916 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2146.9890581175255 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2112.762430440487 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2132.912700371836 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2124.761220389265 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2026.5990514046553 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2162.9735621679947 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2157.0025473854525 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2141.9677693025155 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2145.716748373802 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2139.6432567534675 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2080.9876762774356 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2095.0567589827797 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2083.0972546317826 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2057.0346093762937 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2109.084792439947 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2167.8134816714264 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2082.0276899316555 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2122.67424211618 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2105.3652771478455 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2110.9221310666467 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2131.6387975828015 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2080.4319625751436 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2145.3475251277105 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2107.760357695906 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2165.5274894269387 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2145.730027299238 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2182.899889835416 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2184.9798535244176 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2158.2196306339883 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2145.5808667297497 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2118.6544420362447 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2165.7339109175227 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2118.0222195685405 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2153.1002593737658 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2114.8286128405707 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2140.1224643043765 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2164.521124665876 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2137.2841729511547 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2197.6042391251062 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2144.9861522912543 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2066.8306294874246 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2155.531451814041 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2234.3586125917955 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2181.248290366225 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2068.9157563240283 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2149.6385227731507 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2151.8862849217003 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2120.4166466846373 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2121.0722286100067 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2192.363049701575 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2102.006470506354 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2170.9400977208024 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2149.1792817148694 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2040.0464638650494 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2148.133822127998 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2101.5205644632897 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2215.7239948507267 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2170.9986105375674 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2243.1770097984586 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2085.834657980998 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2158.410991890668 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2133.845740765127 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2158.0135653284724 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2165.0264601748336 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2198.6382493571914 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2123.820518237858 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2190.5010145478655 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2106.0676405979766 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2084.5265679387635 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2176.043401451154 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2143.1383510922565 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2153.4685858148096 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2158.2296251481016 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2260.5780292618447 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2134.8487525669107 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2101.437286945761 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2176.400758761266 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2181.4135193479956 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2131.980231298344 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2106.8137538210663 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2137.8664830795237 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2098.8864001173606 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2148.5150518451596 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2046.9616057399435 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2128.9362549653824 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2134.865212311185 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2101.1998149545398 ['3 --> 0']
# Dropping ['1', '2'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['3', '0'], dtype='object')
# -2184.9473323254324 ['3 --> 0']
# [-2116.537012960976, -2206.6666983912496, -2217.1988636272845, -2123.6628945979937, -2112.5817920565382, -2055.278761128523, -2200.150879952074, -2102.5424026767396, -2162.448822213287, -2183.020834662385, -2204.474732171035, -2110.9550069544916, -2146.9890581175255, -2112.762430440487, -2132.912700371836, -2124.761220389265, -2026.5990514046553, -2162.9735621679947, -2157.0025473854525, -2141.9677693025155, -2145.716748373802, -2139.6432567534675, -2080.9876762774356, -2095.0567589827797, -2083.0972546317826, -2057.0346093762937, -2109.084792439947, -2167.8134816714264, -2082.0276899316555, -2122.67424211618, -2105.3652771478455, -2110.9221310666467, -2131.6387975828015, -2080.4319625751436, -2145.3475251277105, -2107.760357695906, -2165.5274894269387, -2145.730027299238, -2182.899889835416, -2184.9798535244176, -2158.2196306339883, -2145.5808667297497, -2118.6544420362447, -2165.7339109175227, -2118.0222195685405, -2153.1002593737658, -2114.8286128405707, -2140.1224643043765, -2164.521124665876, -2137.2841729511547, -2197.6042391251062, -2144.9861522912543, -2066.8306294874246, -2155.531451814041, -2234.3586125917955, -2181.248290366225, -2068.9157563240283, -2149.6385227731507, -2151.8862849217003, -2120.4166466846373, -2121.0722286100067, -2192.363049701575, -2102.006470506354, -2170.9400977208024, -2149.1792817148694, -2040.0464638650494, -2148.133822127998, -2101.5205644632897, -2215.7239948507267, -2170.9986105375674, -2243.1770097984586, -2085.834657980998, -2158.410991890668, -2133.845740765127, -2158.0135653284724, -2165.0264601748336, -2198.6382493571914, -2123.820518237858, -2190.5010145478655, -2106.0676405979766, -2084.5265679387635, -2176.043401451154, -2143.1383510922565, -2153.4685858148096, -2158.2296251481016, -2260.5780292618447, -2134.8487525669107, -2101.437286945761, -2176.400758761266, -2181.4135193479956, -2131.980231298344, -2106.8137538210663, -2137.8664830795237, -2098.8864001173606, -2148.5150518451596, -2046.9616057399435, -2128.9362549653824, -2134.865212311185, -2101.1998149545398, -2184.9473323254324]
# MSE =  9.533187149013138
# BIC =  9.55867332284692
# COMB =  9.572324869919198
# Times =  0
# [3] [3.0]
# A =  {('3', '0'), ('3', '2'), ('0', '2'), ('2', '1'), ('3', '1')}
# B =  {('2', '1'), ('3', '1'), ('3', '0'), ('0', '2')}
# A =  {('1', '2'), ('0', '1'), ('0', '2'), ('3', '2'), ('0', '3'), ('3', '1')}
# B =  {('1', '2'), ('3', '1'), ('0', '1'), ('3', '2'), ('0', '3'), ('0', '2')}
# Inputs =  ['0', '2', '3']
# Target =  ['1']
# Descendents =  {2}
# Removing descendants
# Required before [['0', '3'], ['0', '1'], ['0', '2'], ['1', '2'], ['3', '2'], ['3', '1']]
# Removing ['0', '2']
# Removing ['1', '2']
# Removing ['3', '2']
# Required After: [['0', '3'], ['0', '1'], ['3', '1']]
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9365.245634729672 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9368.920026231464 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9405.249970644138 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9371.166871827663 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9405.25018434345 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9381.012878565449 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9396.489460815728 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9392.697676531043 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9361.208032110197 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9332.829169442757 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9357.877080367936 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9344.653341080328 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9401.90482716457 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9346.413556578502 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9339.90436763985 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9289.113709214702 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9298.463774583593 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9336.021523780999 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9373.736064426896 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9359.869920156949 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9393.837192261311 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9374.85420284419 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9380.803850602915 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9402.197676373838 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9410.454615383816 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9290.172464528629 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9350.86020686973 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9329.13001446833 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9335.435592639615 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9350.17121894763 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9355.284108794547 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9315.999180644707 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9403.27989222875 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9420.59317146933 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9415.343440981671 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9321.133658337205 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9340.900207785617 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9380.550204104038 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9412.314687402551 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9292.626009134476 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9369.198056716019 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9376.022458891355 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9362.482659619205 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9431.479456541441 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9317.095049078132 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9388.494544026504 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9483.400915159007 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9341.246758962689 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9463.509990808876 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9364.165100691132 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9367.727145042016 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9455.111431125366 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9392.710505088959 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9435.2449111815 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9371.876414841721 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9375.947163660423 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9355.302070813364 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9410.573887441795 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9357.45636913183 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9316.122085608458 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9334.5468852524 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9383.4983003754 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9383.095173220252 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9427.936833516067 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9390.02756050838 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9420.172858242291 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9352.447665553855 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9367.868719809467 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9372.285264471397 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9424.453340976988 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9414.203477135703 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9317.011923408314 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9299.943089389282 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9431.584575277613 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9345.359819594169 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9393.655349537801 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9388.523540423757 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9430.46136619375 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9390.831282864096 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9363.254167465388 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9373.749811297248 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9431.082522822799 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9337.213240017863 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9359.489271519504 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9359.000420883882 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9339.944812753092 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9305.15901347546 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9374.310788544874 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9350.922096135519 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9407.365813455615 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9436.639928767345 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9346.755437125861 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9359.202833385041 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9350.319076173375 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9333.181102178978 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9395.50413209558 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9362.924028714866 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9421.214005250406 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9391.728514304252 ['0 --> 1', '0 --> 3', '3 --> 1']
# Dropping ['2'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['0', '3', '1'], dtype='object')
# -9320.136037701943 ['0 --> 1', '0 --> 3', '3 --> 1']
# [-9365.245634729672, -9368.920026231464, -9405.249970644138, -9371.166871827663, -9405.25018434345, -9381.012878565449, -9396.489460815728, -9392.697676531043, -9361.208032110197, -9332.829169442757, -9357.877080367936, -9344.653341080328, -9401.90482716457, -9346.413556578502, -9339.90436763985, -9289.113709214702, -9298.463774583593, -9336.021523780999, -9373.736064426896, -9359.869920156949, -9393.837192261311, -9374.85420284419, -9380.803850602915, -9402.197676373838, -9410.454615383816, -9290.172464528629, -9350.86020686973, -9329.13001446833, -9335.435592639615, -9350.17121894763, -9355.284108794547, -9315.999180644707, -9403.27989222875, -9420.59317146933, -9415.343440981671, -9321.133658337205, -9340.900207785617, -9380.550204104038, -9412.314687402551, -9292.626009134476, -9369.198056716019, -9376.022458891355, -9362.482659619205, -9431.479456541441, -9317.095049078132, -9388.494544026504, -9483.400915159007, -9341.246758962689, -9463.509990808876, -9364.165100691132, -9367.727145042016, -9455.111431125366, -9392.710505088959, -9435.2449111815, -9371.876414841721, -9375.947163660423, -9355.302070813364, -9410.573887441795, -9357.45636913183, -9316.122085608458, -9334.5468852524, -9383.4983003754, -9383.095173220252, -9427.936833516067, -9390.02756050838, -9420.172858242291, -9352.447665553855, -9367.868719809467, -9372.285264471397, -9424.453340976988, -9414.203477135703, -9317.011923408314, -9299.943089389282, -9431.584575277613, -9345.359819594169, -9393.655349537801, -9388.523540423757, -9430.46136619375, -9390.831282864096, -9363.254167465388, -9373.749811297248, -9431.082522822799, -9337.213240017863, -9359.489271519504, -9359.000420883882, -9339.944812753092, -9305.15901347546, -9374.310788544874, -9350.922096135519, -9407.365813455615, -9436.639928767345, -9346.755437125861, -9359.202833385041, -9350.319076173375, -9333.181102178978, -9395.50413209558, -9362.924028714866, -9421.214005250406, -9391.728514304252, -9320.136037701943]
# MSE =  10.809401993378984
# BIC =  10.80950553766861
# COMB =  10.804504264256318
# Times =  1
# [3, 3] [3.0, 3.0]
# A =  {('1', '2'), ('2', '3'), ('1', '3'), ('2', '0'), ('0', '3')}
# B =  {('1', '2'), ('2', '3'), ('2', '0'), ('1', '3'), ('0', '3')}
# Inputs =  ['0', '2', '3']
# Target =  ['1']
# Descendents =  {0, 2, 3}
# Removing descendants
# Required before [['0', '3'], ['1', '2'], ['1', '3'], ['2', '0'], ['2', '3']]
# Removing ['0', '3']
# Removing ['2', '0']
# Removing ['1', '2']
# Removing ['2', '3']
# Removing ['1', '3']
# Required After: []
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1791.5701363025094 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1664.1038276893592 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1689.0395355403944 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1643.4977556684344 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1652.1220734717201 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1639.9059747617737 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1558.4670428079457 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1770.9788953411835 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1605.155227252121 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1711.804167221604 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1795.4913446584192 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1684.4771704679504 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1663.0134883562237 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1754.7739047831203 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1748.7210849496535 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1746.6057961311615 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1679.0321117313201 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1589.455084875879 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1688.8772097271349 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1773.622429494037 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1664.0133614373924 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1739.4317914266633 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1601.3096183496993 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1598.8645764003907 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1727.9610683127967 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1593.1957924898077 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1755.5192947546186 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1649.374425947828 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1722.583756258095 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1755.6478669734547 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1742.213457351637 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1765.6808993791299 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1733.2103851358995 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1667.6348578451568 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1720.6084540758636 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1623.9557768458585 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1630.4315608556453 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1677.04706094644 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1734.4194246293239 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1738.196214480692 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1779.8131881514023 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1674.1707524640854 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1782.3974243445516 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1632.4944198705875 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1579.4840074863657 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1645.1292995198146 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1611.925421814143 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1823.2093276425949 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1681.979272408367 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1671.1231909995613 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1687.4713606708535 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1768.9914806680893 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1861.3391142048777 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1611.6830038659677 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1609.4790202285758 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1699.3899694491765 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1688.469299237571 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1675.891071257951 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1683.0665639113572 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1741.059971584016 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1731.4333025784617 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1675.5906791229677 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1687.193040307273 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1814.2551131182995 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1597.5198192716794 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1654.0318725250454 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1702.3443492679864 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1740.8968780104597 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1658.639427446335 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1662.5633921862118 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1695.826965490762 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1643.0612881784737 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1698.4890393508174 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1657.7972744697968 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1691.8887771122281 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1723.9035899258556 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1690.2934171960117 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1651.3986975903217 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1669.1716141866991 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1673.70913317427 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1719.3979919617257 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1689.1358006428127 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1686.8937395293265 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1754.4849975751195 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1761.231557793211 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# Causal_df  Index(['1'], dtype='object')
# 1696.7732955802921 ['']
# Dropping ['0', '2', '3'] Index(['0', '2', '3', '1'], dtype='object')
# ...
# 1547.427002711045 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1569.4494628743716 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1468.4072632212872 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1492.8888808109473 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1532.3208376557295 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1559.43067892506 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1579.0630835128882 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1455.0950815919437 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1426.870030921823 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1491.1668579234508 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1440.4678700264294 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1535.6558137938198 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1503.6429272894143 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1593.0224174722578 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1510.1743736654428 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1562.157112507728 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1553.5358864435518 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1474.7558104606733 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1461.4050793624149 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1544.1083942995283 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1550.4241910881547 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1436.3933277251338 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1510.6805428618666 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1518.1305950536025 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1560.9833386091427 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1504.365454527083 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1568.3264547332408 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1485.5867316911133 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1551.2138408231588 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1577.4618399666015 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1467.1892434337 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1424.6881435134176 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1528.2428434875003 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1584.5858607213895 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1492.943593205787 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1449.776044168239 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1483.7182274988188 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1569.0587744248462 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1537.443558556367 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1475.2881883366992 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1486.8543053914425 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1457.862178302623 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1485.5379899355623 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1512.4076482166565 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1534.8932120689926 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1488.0354277467193 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1492.6311243432929 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1557.1484803509672 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1590.6812817452876 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1466.9317131560733 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1482.7209001797232 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1381.5288230180593 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1545.144266147159 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1429.748186275255 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1521.547035580638 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1583.9575520465967 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1497.182923326423 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1563.2159070002535 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1518.6824176543932 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1629.1420319523493 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1495.3051780470894 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1491.7570386164803 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1555.5136956913682 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1482.8810939124842 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1524.4134279636319 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1658.819365680383 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1464.0805461062673 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1469.6668385597566 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1482.211729130965 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1530.9939608287154 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1482.5337424073707 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1385.1325969724535 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1506.9819807578626 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1491.3909260556331 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1517.462509725066 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1555.5022535233588 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1527.3320169445822 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1493.5394215431104 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1513.250473837961 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1543.6591121281797 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1473.6905714094653 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1467.9469659798685 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1508.0133291419804 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1502.9586952485151 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1539.7548360500464 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1468.6534368642933 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1391.627552328943 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1539.9355268902143 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1594.0206643503027 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1519.019515543068 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1518.5237562892507 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1389.654431538134 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1505.318078324973 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1461.8663243697122 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1440.406889578368 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1489.934706635847 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1511.4328485073509 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1555.453301522299 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1543.3415049375767 ['']
# Dropping ['0', '1', '2'] Index(['0', '1', '2', '3'], dtype='object')
# Causal_df  Index(['3'], dtype='object')
# 1507.0746205161315 ['']
# [1547.427002711045, 1569.4494628743716, 1468.4072632212872, 1492.8888808109473, 1532.3208376557295, 1559.43067892506, 1579.0630835128882, 1455.0950815919437, 1426.870030921823, 1491.1668579234508, 1440.4678700264294, 1535.6558137938198, 1503.6429272894143, 1593.0224174722578, 1510.1743736654428, 1562.157112507728, 1553.5358864435518, 1474.7558104606733, 1461.4050793624149, 1544.1083942995283, 1550.4241910881547, 1436.3933277251338, 1510.6805428618666, 1518.1305950536025, 1560.9833386091427, 1504.365454527083, 1568.3264547332408, 1485.5867316911133, 1551.2138408231588, 1577.4618399666015, 1467.1892434337, 1424.6881435134176, 1528.2428434875003, 1584.5858607213895, 1492.943593205787, 1449.776044168239, 1483.7182274988188, 1569.0587744248462, 1537.443558556367, 1475.2881883366992, 1486.8543053914425, 1457.862178302623, 1485.5379899355623, 1512.4076482166565, 1534.8932120689926, 1488.0354277467193, 1492.6311243432929, 1557.1484803509672, 1590.6812817452876, 1466.9317131560733, 1482.7209001797232, 1381.5288230180593, 1545.144266147159, 1429.748186275255, 1521.547035580638, 1583.9575520465967, 1497.182923326423, 1563.2159070002535, 1518.6824176543932, 1629.1420319523493, 1495.3051780470894, 1491.7570386164803, 1555.5136956913682, 1482.8810939124842, 1524.4134279636319, 1658.819365680383, 1464.0805461062673, 1469.6668385597566, 1482.211729130965, 1530.9939608287154, 1482.5337424073707, 1385.1325969724535, 1506.9819807578626, 1491.3909260556331, 1517.462509725066, 1555.5022535233588, 1527.3320169445822, 1493.5394215431104, 1513.250473837961, 1543.6591121281797, 1473.6905714094653, 1467.9469659798685, 1508.0133291419804, 1502.9586952485151, 1539.7548360500464, 1468.6534368642933, 1391.627552328943, 1539.9355268902143, 1594.0206643503027, 1519.019515543068, 1518.5237562892507, 1389.654431538134, 1505.318078324973, 1461.8663243697122, 1440.406889578368, 1489.934706635847, 1511.4328485073509, 1555.453301522299, 1543.3415049375767, 1507.0746205161315]
# MSE =  9.655365177965246
# BIC =  9.628010453193061
# COMB =  9.638301031007504
# Times =  22
# [3, 3, 2, 3, 3, 3, 2, 3, 3, 1, 3, 3, 3, 1, 3, 3, 3, 3, 3, 3, 3, 3, 3] [3.0, 3.0, 2.5, 3.0, 3.0, 3.0, 1.5, 3.0, 3.0, 2.0, 2.5, 3.0, 3.0, 2.0, 3.0, 3.0, 3.0, 2.5, 2.0, 3.0, 3.0, 3.0, 3.0]
# A =  {('3', '0'), ('0', '1'), ('0', '2'), ('3', '2'), ('2', '1'), ('3', '1')}
# B =  {('3', '0'), ('3', '2'), ('0', '1'), ('2', '1'), ('0', '2')}
# A =  {('1', '2'), ('0', '1'), ('0', '2'), ('3', '2'), ('0', '3'), ('3', '1')}
# B =  {('1', '2'), ('0', '1'), ('0', '2'), ('3', '2'), ('0', '3'), ('3', '1')}
# Inputs =  ['0', '2', '3']
# Target =  ['1']
# Descendents =  {2}
# Removing descendants
# Required before [['0', '3'], ['0', '2'], ['0', '1'], ['1', '2'], ['3', '1'], ['3', '2']]
# Removing ['0', '2']
# Removing ['1', '2']
# Removing ['3', '2']
# Required After: [['0', '3'], ['0', '1'], ['3', '1']]

# %%
def get_bic(df, prior, penalty = 2):

    tetrad.run(algoId = 'gfci', dfs = df, testId= 'sem-bic', scoreId = 'sem-bic', dataType = 'continuous',
               structurePrior = 1.0, samplePrior = 1, maxDegree = -1, maxPathLength = -1, priorKnowledge = prior,
               completeRuleSetUsed = False, faithfulnessAssumed = True, verbose = True, penalty = 200
               )
    
    BIC = tetrad.getTetradGraph().getAllAttributes().toString()
    BIC = float(BIC.split('=')[-1].split('}')[0])
    return BIC #/ len(df)

get_bic(causal_df, prior)
tetrad.getEdges()
tetrad.getTetradGraph().getAllAttributes().toString()
# Out:
# '{BIC=24479.609410385827}'

# %%
prior
# Out:
# Instance of edu.cmu.tetrad.data.Knowledge2: /knowledge
# addtemporal
#
#
# forbiddirect
#
# requiredirect

# %%
def get_average_improvement(df1, df2):
    ret = []
    for i, j in zip(df1,df2):
        ret.append(np.sum(j) - np.sum(i))
    return ret

improvement = get_average_improvement(bestMSE, bestCOMBO)
np.mean(improvement), np.std(improvement)


fig, ax = plt.subplots()
ax.plot(averageDegree,improvement, '.')
plt.show()


fig, ax = plt.subplots()
ax.plot(targetDegree,improvement, '.')
plt.show()


fig, ax = plt.subplots()
ax.plot(target_inD,improvement, '.')
plt.show()

fig, ax = plt.subplots()
ax.plot(target_outD,improvement, '.')
plt.show()

fig, ax = plt.subplots()
ax.plot(descendants,improvement, '.')
plt.show()

# %%
def box_plots(X,Y):
    box = []
    for i in np.unique(X):
        box.append([])
    for x,y in zip(X, Y):
        box[x].append(y)
    fig = plt.figure()

    ax = fig.add_subplot(111)
    ax.yaxis.grid(True)
    ax.set_xlabel("Number of Target Descendants")
    ax.set_ylabel("L1 Loss Improvement")
    bp = ax.boxplot(box, showfliers=False, labels = ['0', '1', '2', '3'])
    
box_plots(descendants, improvement)
box_plots(target_outD, improvement)
box_plots(target_inD, improvement)

# %%
improvement
# Out:
# [-0.0006374884583220108,
#  -0.006563246319611693,
#  -0.08639814275495183,
#  -0.012051385986666219,
#  -0.11623136253577826,
#  -0.06894619367183097,
#  -0.005687500426425629,
#  0.011421395275242219,
#  -0.030980521111590775,
#  -0.07769497735489495,
#  -0.013953467757497506,
#  -0.07182149830688545,
#  -0.06750572657882614,
#  -0.11798691961421426,
#  0.00014111544140860133,
#  -0.09454733546234095,
#  -0.025946347490421573,
#  0.038575160630568206,
#  -0.11114299829187502,
#  -0.004607830961333548,
#  -0.06861635263062027,
#  -0.03964305062158857,
#  -0.014393199871918227,
#  0.003043837285744644,
#  0.00018810081359710296,
#  0.06084163368302242,
#  -0.12353300626129382,
#  -0.005139306002881483,
#  -0.0223672457858477,
#  -0.004822748445935332,
#  -0.014111734162607803,
#  0.005979404410169309,
#  -0.00447140468689966,
#  -0.009402449231135535,
#  -0.011772320188164542,
#  -0.018237038592005206]

# %%
np.mean(bestMSE), np.mean(bestCOMBO), np.std(bestMSE), np.std(bestCOMBO), np.mean(averageDegree),np.std(averageDegree), np.mean(targetDegree), np.std(targetDegree)
# Out:
# (1.4445040749237175,
#  1.4423262172517248,
#  0.35756226510125927,
#  0.35495020909793984,
#  2.735294117647059,
#  0.4575396819442366,
#  2.764705882352941,
#  0.42418250299576343)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-05dc37c61656> in <module>()
# ----> 1 G.get_edge_data(target)
#
# TypeError: get_edge_data() missing 1 required positional argument: 'v'

# %%
improvement
fig, ax = plt.subplots()
ax.plot(averageDegree,improvement, '.')
plt.show()

improvement
fig, ax = plt.subplots()
ax.plot(targetDegree,improvement, '.')
plt.show()


improvement
fig, ax = plt.subplots()
ax.plot(target_inD,improvement, '.')
plt.show()

improvement
fig, ax = plt.subplots()
ax.plot(target_outD,improvement, '.')
plt.show()

# %%
fig, ax = plt.subplots()
b,m = polyfit(proposed,generalization, 1)
text(0.05, 0.9,'Pearson coeff:' + str(pearsonr(proposed,generalization)[0])[0:4], ha='left', va='center', transform=ax.transAxes)
ax.plot(proposed,generalization, '.')
plt.plot(proposed, b + m * np.array(proposed), '-')
ax.set_xlabel("BIC")
ax.set_ylabel("GEN")
fig.savefig('Ex4MSEVsAUS.pdf', bbox_inches='tight')
plt.show()

fig, ax = plt.subplots()
b,m = polyfit(metrics,generalization, 1)
text(0.05, 0.9,'Pearson coeff:' + str(pearsonr(metrics,generalization)[0])[0:4], ha='left', va='center', transform=ax.transAxes)
ax.plot(metrics,generalization, '.')
plt.plot(metrics, b + m * np.array(metrics), '-')
ax.set_xlabel("MSE")
ax.set_ylabel("GEN")
fig.savefig('Ex4MSEVsAUS.pdf', bbox_inches='tight')
plt.show()


total = normalize(metrics) + normalize(proposed)
fig, ax = plt.subplots()
b,m = polyfit(total,generalization, 1)
text(0.05, 0.9,'Pearson coeff:' + str(pearsonr(total,generalization)[0])[0:4], ha='left', va='center', transform=ax.transAxes)
ax.plot(total,generalization, '.')
plt.plot(total, b + m * np.array(total), '-')
ax.set_xlabel("MSE")
ax.set_ylabel("GEN")
fig.savefig('Ex4MSEVsAUS.pdf', bbox_inches='tight')
plt.show()

# %%
nbest = 10
final = pd.DataFrame(np.stack((metrics, proposed, total, generalization), axis = 1), columns = ['metrics', 'proposed', 'combined', 'generalization'])
print("MSE = ", np.sum(final.nsmallest(nbest, 'metrics')['generalization']))
print("BIC = ", np.sum(final.nsmallest(nbest, 'proposed')['generalization']))
print("COMB = ",np.sum(final.nsmallest(nbest, 'combined')['generalization']))
