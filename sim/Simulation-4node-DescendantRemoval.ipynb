# %%
import configparser
import random
import numpy as np
import tensorflow as tf
from sklearn.metrics import roc_auc_score, average_precision_score
from keras.models import load_model
from keras.callbacks import LearningRateScheduler, ModelCheckpoint, Callback
from keras.applications.inception_resnet_v2 import InceptionResNetV2
from keras.models import load_model, Model
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, BatchNormalization, \
                        Input, Dense, GlobalAveragePooling2D, Dropout
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
from keras import optimizers
from keras.utils import to_categorical
from collections import Counter
import keras.optimizers
from keras.callbacks import Callback
from keras.callbacks import EarlyStopping
from keras.utils import plot_model
import glob, os
import tensorflow as tf
import pandas as pd
from random import shuffle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
from sklearn.metrics import roc_auc_score, average_precision_score, mean_absolute_error, accuracy_score
from sklearn.model_selection import StratifiedKFold
from sklearn.linear_model import LogisticRegression, Perceptron
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import GaussianNB, BernoulliNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, AdaBoostClassifier, BaggingClassifier, GradientBoostingClassifier
from sklearn.neural_network import MLPClassifier
import pandas as pd
from pycausal import search as s
from pycausal.pycausal import pycausal as pc
from collections import defaultdict
from numpy.polynomial.polynomial import polyfit  
from scipy.stats import pearsonr
from pylab import text
from pycausal import prior as p
import itertools

# select your GPU Here
os.environ["CUDA_VISIBLE_DEVICES"]="" #Comment this line out if you want all GPUS (2 hehe)

# python full-display web browser
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))


def get_model(dense, dropouts, inputs):
    # dense is an ordered list of the number of dense neurons like [1024, 2048, 1024]
    # dropouts is an ordered list of the dropout masks like [0.2, 0.3, 0.4]
    inputs = keras.Input(shape = (inputs,))
    x = keras.layers.Dense(dense[0], activation = 'relu')(inputs)
    x = keras.layers.Dropout(dropouts[0])(x, training=False)
    for den, drop in zip(dense[1:], dropouts[1:]):
        x = keras.layers.Dense(den, activation = 'relu')(x)
        x = keras.layers.Dropout(drop)(x, training=False)
    outputs = keras.layers.Dense(1, activation = 'linear')(x)
    model = keras.Model(inputs, outputs)
    return model

def get_bic(df, prior, penalty = 2):

    tetrad.run(algoId = 'gfci', dfs = df, testId= 'sem-bic', scoreId = 'sem-bic', dataType = 'continuous',
               structurePrior = 1.0, samplePrior = 1, maxDegree = -1, maxPathLength = -1, priorKnowledge = prior,
               completeRuleSetUsed = False, faithfulnessAssumed = True, verbose = True, penalty = 200
               )
    
    BIC = tetrad.getTetradGraph().getAllAttributes().toString()
    BIC = float(BIC.split('=')[-1].split('}')[0])
    return BIC #/ len(df)


def normalize(a):
    return (a - np.min(a)) / (np.max(a) - np.min(a))
def make_categorical(df, complete_df, categoricals):   
    retval = None
    for key in df.columns:
        if retval is not None:
            if key in categoricals:
                retval = np.concatenate((retval, to_categorical(df[key], len(complete_df[key].unique()))), axis = 1)
            else:
                retval = np.concatenate((retval, df[key].values[...,np.newaxis]), axis = 1)
        else:
            if key in categoricals:
                retval = to_categorical(df[key], len(complete_df[key].unique()))
            else:
                retval = df[key]
    return retval
num_models = 100   
pc = pc()
pc.start_vm(java_max_heap_size = '11000M')
tetrad = s.tetradrunner()

models = []
model_names = []



randomize = False
if randomize:
    layers = [256, 512, 1024, 2048, 4096]
    for i in range(num_models):
        network = []
        for j in range(3):
            network.append(layers[random.randint(0,len(layers) -1)])
        models.append(network)
        model_names.append('temp/sim' + str(i))
    print(models, model_names)    
else:
    model_layers = [512, 256]
    for i in range(num_models):
        models.append(model_layers)
        model_names.append('temp/sim' + str(i))

print(models, model_names)
# Out:
# /home/tkyono/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# /home/tkyono/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# <style>.container { width:100% !important; }</style>
# [[512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256], [512, 256]] ['temp/sim0', 'temp/sim1', 'temp/sim2', 'temp/sim3', 'temp/sim4', 'temp/sim5', 'temp/sim6', 'temp/sim7', 'temp/sim8', 'temp/sim9', 'temp/sim10', 'temp/sim11', 'temp/sim12', 'temp/sim13', 'temp/sim14', 'temp/sim15', 'temp/sim16', 'temp/sim17', 'temp/sim18', 'temp/sim19', 'temp/sim20', 'temp/sim21', 'temp/sim22', 'temp/sim23', 'temp/sim24', 'temp/sim25', 'temp/sim26', 'temp/sim27', 'temp/sim28', 'temp/sim29', 'temp/sim30', 'temp/sim31', 'temp/sim32', 'temp/sim33', 'temp/sim34', 'temp/sim35', 'temp/sim36', 'temp/sim37', 'temp/sim38', 'temp/sim39', 'temp/sim40', 'temp/sim41', 'temp/sim42', 'temp/sim43', 'temp/sim44', 'temp/sim45', 'temp/sim46', 'temp/sim47', 'temp/sim48', 'temp/sim49', 'temp/sim50', 'temp/sim51', 'temp/sim52', 'temp/sim53', 'temp/sim54', 'temp/sim55', 'temp/sim56', 'temp/sim57', 'temp/sim58', 'temp/sim59', 'temp/sim60', 'temp/sim61', 'temp/sim62', 'temp/sim63', 'temp/sim64', 'temp/sim65', 'temp/sim66', 'temp/sim67', 'temp/sim68', 'temp/sim69', 'temp/sim70', 'temp/sim71', 'temp/sim72', 'temp/sim73', 'temp/sim74', 'temp/sim75', 'temp/sim76', 'temp/sim77', 'temp/sim78', 'temp/sim79', 'temp/sim80', 'temp/sim81', 'temp/sim82', 'temp/sim83', 'temp/sim84', 'temp/sim85', 'temp/sim86', 'temp/sim87', 'temp/sim88', 'temp/sim89', 'temp/sim90', 'temp/sim91', 'temp/sim92', 'temp/sim93', 'temp/sim94', 'temp/sim95', 'temp/sim96', 'temp/sim97', 'temp/sim98', 'temp/sim99']

# %%
import networkx as nx

def random_dag(nodes, edges):
    """Generate a random Directed Acyclic Graph (DAG) with a given number of nodes and edges."""
    G = nx.DiGraph()
    for i in range(nodes):
        G.add_node(i)
    while edges > 0:
        a = random.randint(0,nodes-1)
        b=a
        while b==a:
            b = random.randint(0,nodes-1)
        G.add_edge(a,b)
        if nx.is_directed_acyclic_graph(G):
            edges -= 1
        else:
            # we closed a loop!
            G.remove_edge(a,b)
    return G

# %%
import pydot
from IPython.display import SVG

def examine_graph_continuous(df, prior = None):
    tetrad.run(algoId = 'fges', dfs = df,  scoreId = 'sem-bic', dataType = 'continuous',
               structurePrior = 1.0, samplePrior = 1, maxDegree = -1, maxPathLength = -1, priorKnowledge = prior,
               completeRuleSetUsed = False, faithfulnessAssumed = True, verbose = True,
               )
    return tetrad.getTetradGraph()

def gen_data(list_vertex = [], list_edges = [], mean = 0, var = 1, SIZE = 20000):
    g = []
    for v in list_vertex:
        g.append(np.random.normal(mean,var,SIZE))
        
    for edge in list_edges:
        g[edge[1]] += g[edge[0]]
    g = np.swapaxes(g,0,1)
    return pd.DataFrame(g, columns = list(map(str, list_vertex)))

# %%
bestMSE = []
bestBIC = []
bestCOMBO = []
averageDegree = []
targetDegree = []
target_inD = []
target_outD = []
descendants = []
t= 0
while (t < 30):
    train_size = 20000
    nodes = 4
    test_mean = 1
    test_var = 2
    test_size = 2000
    
    G = random_dag(nodes, random.randint(nodes, nodes*nodes)) # since max number of edges is n^2
    df = gen_data(np.arange(nodes), G.edges, SIZE = train_size)
    require = []
    for i in G.edges:
        require.append([str(i[0]), str(i[1])])  
    prior = p.knowledge(requiredirect = require)
    examine_graph_continuous(df, prior)
    
    # Check to make sure that graph matches our prior knowledge. Or else abort this test.
    a = set()
    for i in tetrad.getEdges():
        a.add((i[0], i[-1]))
    b = set()
    for i in require:
        b.add((i[0], i[1]))
    print("A = ", a)
    print("B = ", b)
    if a != b:
        continue
        
    known_conx = set({})
    for i in tetrad.getEdges():
        if ' --> ' in i:
            known_conx.add((i.split(' --> ')[0], i.split(' --> ')[1]))
    known_conx
        
    # Need to set our inputs and outputs
    inputs = set(np.arange(nodes))
    target = str(a.pop()[random.randint(0,1)])
    inputs.remove(int(target))
    inputs = list(map(str, inputs))
    df_test = gen_data(np.arange(nodes), G.edges, mean = test_mean, var = test_var, SIZE = test_size)
    target = [target]
    
    print("Inputs = ", inputs)
    print("Target = ", target)
    
    descend = nx.descendants(G, int(target[0]))
    print("Descendents = ", descend)
        
    
    # now let's remove them. from the DAG.
    print("Removing descendants")
    print("Required before", require)
    for d in descend:
        for r in require.copy():
            if str(d) in r:
                print("Removing", r)
                require.remove(r)
    
    print("Required After:", require)
    # update our prior....
    prior = p.knowledge(requiredirect = require)
    
    #df.drop(df_test.index, inplace = True)
    #df_test.reset_index(inplace = True)
    #df.sample(frac= 1).reset_index(inplace = True) # this will shuffle and reset index

    x_test = df_test[inputs]
    y_test = df_test[target]

    causal_split = 0.2
    val_split = 0.2
    train_split = 1 - (causal_split + val_split)

    x_causal = df[inputs][-int(causal_split * len(df)) :]
    y_causal = df[target][-int(causal_split * len(df)) :]

    x_val = df[inputs][int(train_split * len(df)):-int(causal_split * len(df))]
    y_val = df[target][int(train_split * len(df)):-int(causal_split * len(df))]

    x_train = df[inputs][:int(train_split * len(df))]
    y_train = df[target][:int(train_split * len(df))]

    verbosity = 0

    for idx, model_name in enumerate(model_names):
        if type(models[idx]) is list:
            #clear session
            keras.backend.clear_session() 
            #get model according to specification
            model = get_model(models[idx], [0.2] * len(models), np.shape(x_train)[1])
            callbacks = [ModelCheckpoint(model_name, verbose= verbosity, monitor='val_loss',save_best_only=True), 
                         EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=2, verbose= verbosity, mode='auto')]
            model.compile(optimizer = optimizers.SGD(lr = 0.0001, momentum = 0.9, ), loss='mean_squared_error', metrics = ['mse'])
            #print(len(X), len(y))
            model.fit(x_train, y_train, epochs = 20, validation_data = (x_val, y_val), callbacks = callbacks, batch_size = 32, verbose = verbosity)
        else:
            models[idx].fit(X,y)





    generalization = []
    metrics = []
    proposed = []
    x_causal.reset_index(drop=True, inplace = True)
    for idx, model_name in enumerate(model_names):
        #print(model_name)
        if type(models[idx]) is list:
            keras.backend.clear_session()
            model = load_model(model_name)
        else:
            model = models[idx]

        y_pred = model.predict(x_test)
        generalization.append(mean_absolute_error(y_pred, y_test))

        #### CHECK FOR CAUSAL METRIC HERE
        y_causal_pred = model.predict(x_causal)
        causal_targets = pd.DataFrame(y_causal_pred, columns = target)
        
        #causal_targets.reset_index(drop=True, inplace = True)
        causal_df = x_causal.join(causal_targets)
        print("Dropping", list(map(str, descend)), causal_df.columns)
        causal_df.drop(columns = list(map(str, descend)), inplace = True)

        print("Causal_df ", causal_df.columns)

        metrics.append(mean_absolute_error(y_causal_pred, y_causal))
        #print(x_causal.head)
        bic_pred = get_bic(causal_df, prior)
        #print(bic_pred, tetrad.getEdges())

        
        proposed.append(bic_pred)
        print(bic_pred, tetrad.getEdges())   
            #metrics = metrics[:-1]
            #generalization = generalization[:-1]
    nbest = 10
    print(proposed)
    total = normalize(metrics) + normalize(proposed)
    final = pd.DataFrame(np.stack((metrics, proposed, total, generalization), axis = 1), columns = ['metrics', 'proposed', 'combined', 'generalization'])
    print("MSE = ", np.sum(final.nsmallest(nbest, 'metrics')['generalization'].values))
    print("BIC = ", np.sum(final.nsmallest(nbest, 'proposed')['generalization'].values))
    print("COMB = ",np.sum(final.nsmallest(nbest, 'combined')['generalization'].values))
    bestMSE.append(final.nsmallest(nbest, 'metrics')['generalization'].values)
    bestBIC.append(final.nsmallest(nbest, 'proposed')['generalization'].values)
    bestCOMBO.append(final.nsmallest(nbest, 'combined')['generalization'].values)
    print("Times = ", t)
    d = []
    for i in G.degree():
        d.append(i[1])
        if str(i[0]) in target:
            targetDegree.append(i[1])
    averageDegree.append(np.mean(d))
    target_inD.append(G.in_degree(int(target[0])))
    target_outD.append(G.out_degree(int(target[0])))
    descendants.append(len(nx.descendants(G, int(target[0]))))
    print(targetDegree, averageDegree)
    t += 1
    
np.mean(bestMSE), np.mean(bestCOMBO), np.std(bestMSE), np.std(bestCOMBO)
# Out:
# A =  {('0', '3'), ('1', '2'), ('1', '3'), ('1', '0')}
# B =  {('0', '3'), ('1', '2'), ('1', '0')}
# A =  {('0', '1'), ('0', '3'), ('3', '1'), ('2', '1')}
# B =  {('0', '1'), ('2', '1'), ('3', '1'), ('0', '3')}
# Inputs =  ['1', '2', '3']
# Target =  ['0']
# Descendents =  {1, 3}
# Removing descendants
# Required before [['0', '1'], ['0', '3'], ['2', '1'], ['3', '1']]
# Removing ['0', '1']
# Removing ['2', '1']
# Removing ['3', '1']
# Removing ['0', '3']
# Required After: []
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1333.28896450519 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1330.3493408886782 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1389.4480228806663 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1361.2218424265955 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1370.9519396741496 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1390.768682072279 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1341.8855349521355 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1366.2148996031567 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1325.8969831943814 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1268.598037416891 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1457.1590684759246 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1345.5173942928084 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1374.1947509770575 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1417.51692960064 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1372.1482293678773 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1335.0036221976989 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1335.1683874078133 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1287.6095588802684 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1328.1941360839778 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1405.0792256780621 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1522.1762670737069 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1352.343561317685 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1327.9043618899657 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1431.1293803075746 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1343.216383498171 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1377.2985352847722 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1412.8101048768435 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1349.628047003879 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1303.6300840241577 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1283.5550955485462 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1363.6752189004312 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1473.3388445231703 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1419.7219585585324 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1434.864297587194 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1407.4748664653061 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1287.1319947927238 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1332.923189418566 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1332.5536138940106 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1485.2662973678202 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1411.1501073441073 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1452.0482833783221 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1295.343378911002 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1477.5043434532422 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1383.6744277670896 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1405.345891118091 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1303.5428151543547 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1349.2356914994937 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1470.7911692477826 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1509.666352108127 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1336.4020801832175 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1410.3993874462133 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1249.8559936821155 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1328.9687733993248 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1349.1346658105267 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1308.9796368016546 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1357.1796746004088 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1329.5990851686101 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1347.2776472238363 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1377.2171615847642 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1380.7929351425519 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1439.1180516334189 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1333.1132686497315 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1353.8010233032157 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1330.3754828048843 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1404.112214388574 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1453.58040415141 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1407.2952705664834 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1433.920263126235 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1387.6213953095403 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1371.0512392977184 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1394.27770789857 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1468.5344990471458 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1377.2246471466735 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1337.0111194849314 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1337.9770981004078 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1280.9865850518136 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1381.7808748750936 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1428.5254252503132 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1430.772571106994 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1330.9969804167542 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1386.0725710820589 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1450.5474463643104 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1319.806580739853 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1370.764864801378 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1411.1428358227497 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1324.451456958926 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1389.6339988611621 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1365.5501275344182 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1397.3799117839003 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1319.9852625322449 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1390.5311395502765 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1382.7411328480914 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1375.6647055817582 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1255.9606068977887 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1423.7635492146833 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1420.184584363349 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1330.256633660718 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1335.4502644152346 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1271.865448032239 ['']
# Dropping ['1', '3'] Index(['1', '2', '3', '0'], dtype='object')
# Causal_df  Index(['2', '0'], dtype='object')
# 1336.4676406494127 ['']
# [1333.28896450519, 1330.3493408886782, 1389.4480228806663, 1361.2218424265955, 1370.9519396741496, 1390.768682072279, 1341.8855349521355, 1366.2148996031567, 1325.8969831943814, 1268.598037416891, 1457.1590684759246, 1345.5173942928084, 1374.1947509770575, 1417.51692960064, 1372.1482293678773, 1335.0036221976989, 1335.1683874078133, 1287.6095588802684, 1328.1941360839778, 1405.0792256780621, 1522.1762670737069, 1352.343561317685, 1327.9043618899657, 1431.1293803075746, 1343.216383498171, 1377.2985352847722, 1412.8101048768435, 1349.628047003879, 1303.6300840241577, 1283.5550955485462, 1363.6752189004312, 1473.3388445231703, 1419.7219585585324, 1434.864297587194, 1407.4748664653061, 1287.1319947927238, 1332.923189418566, 1332.5536138940106, 1485.2662973678202, 1411.1501073441073, 1452.0482833783221, 1295.343378911002, 1477.5043434532422, 1383.6744277670896, 1405.345891118091, 1303.5428151543547, 1349.2356914994937, 1470.7911692477826, 1509.666352108127, 1336.4020801832175, 1410.3993874462133, 1249.8559936821155, 1328.9687733993248, 1349.1346658105267, 1308.9796368016546, 1357.1796746004088, 1329.5990851686101, 1347.2776472238363, 1377.2171615847642, 1380.7929351425519, 1439.1180516334189, 1333.1132686497315, 1353.8010233032157, 1330.3754828048843, 1404.112214388574, 1453.58040415141, 1407.2952705664834, 1433.920263126235, 1387.6213953095403, 1371.0512392977184, 1394.27770789857, 1468.5344990471458, 1377.2246471466735, 1337.0111194849314, 1337.9770981004078, 1280.9865850518136, 1381.7808748750936, 1428.5254252503132, 1430.772571106994, 1330.9969804167542, 1386.0725710820589, 1450.5474463643104, 1319.806580739853, 1370.764864801378, 1411.1428358227497, 1324.451456958926, 1389.6339988611621, 1365.5501275344182, 1397.3799117839003, 1319.9852625322449, 1390.5311395502765, 1382.7411328480914, 1375.6647055817582, 1255.9606068977887, 1423.7635492146833, 1420.184584363349, 1330.256633660718, 1335.4502644152346, 1271.865448032239, 1336.4676406494127]
# MSE =  9.489392499499484
# BIC =  9.563703685934048
# COMB =  9.531990848449688
# Times =  0
# [2] [2.0]
# A =  {('0', '2'), ('1', '3'), ('3', '0'), ('1', '0'), ('3', '2'), ('1', '2')}
# B =  {('0', '2'), ('1', '3'), ('3', '0'), ('1', '0'), ('3', '2'), ('1', '2')}
# Inputs =  ['0', '1', '3']
# Target =  ['2']
# Descendents =  set()
# Removing descendants
# Required before [['0', '2'], ['1', '3'], ['1', '0'], ['1', '2'], ['3', '0'], ['3', '2']]
# Required After: [['0', '2'], ['1', '3'], ['1', '0'], ['1', '2'], ['3', '0'], ['3', '2']]
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17528.017295998765 ['1 --> 0', '0 --> 2', '1 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17594.789198580533 ['0 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17607.134879922596 ['0 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17603.276044031325 ['1 --> 0', '0 --> 2', '3 --> 0', '1 --> 2', '3 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17656.974444599644 ['1 --> 0', '0 --> 2', '3 --> 0', '1 --> 2', '3 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17474.252964329597 ['1 --> 0', '0 --> 2', '3 --> 0', '1 --> 2', '3 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17516.18397613654 ['0 --> 2', '3 --> 0']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17704.95301000306 ['1 --> 0', '0 --> 2', '1 --> 2', '3 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17502.28031879528 ['1 --> 0', '0 --> 2', '3 --> 0', '1 --> 2', '3 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17551.558464464262 ['0 --> 2', '1 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17531.763836986847 ['0 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17543.484905360558 ['1 --> 0', '0 --> 2', '1 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17567.65096407388 ['0 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17587.253521576742 ['0 --> 2', '1 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17615.66298792793 ['1 --> 0', '0 --> 2', '3 --> 0', '1 --> 2', '3 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17662.637393960038 ['1 --> 0', '0 --> 2', '1 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17629.66958640447 ['1 --> 0', '0 --> 2', '3 --> 0', '1 --> 2', '3 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17507.41884170113 ['1 --> 0', '0 --> 2', '1 --> 2', '3 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17568.705748135526 ['1 --> 0', '0 --> 2', '1 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17573.61595161299 ['0 --> 2', '3 --> 0', '3 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17478.493304595682 ['0 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17617.002127746964 ['0 --> 2', '3 --> 0', '1 --> 2', '3 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17556.754335648944 ['1 --> 0', '0 --> 2', '3 --> 0', '1 --> 2', '3 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17553.268013848647 ['1 --> 0', '0 --> 2', '3 --> 0', '1 --> 2', '3 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17649.28218063217 ['0 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17530.20036384427 ['1 --> 0', '0 --> 2', '1 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17498.2042625761 ['0 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17594.89181597412 ['1 --> 0', '0 --> 2', '3 --> 0', '1 --> 2', '3 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17555.33741824989 ['1 --> 0', '0 --> 2', '1 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17613.287997451407 ['1 --> 0', '0 --> 2', '3 --> 0', '1 --> 2', '3 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17601.880779320556 ['1 --> 0', '0 --> 2', '3 --> 0', '1 --> 2', '3 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17535.208150930386 ['1 --> 0', '0 --> 2', '1 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17570.78339338678 ['1 --> 0', '0 --> 2', '3 --> 0', '1 --> 2', '3 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17539.379628092953 ['0 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17548.858769169878 ['1 --> 0', '0 --> 2', '1 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17601.272913418914 ['1 --> 0', '0 --> 2', '1 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17564.76717989891 ['1 --> 0', '0 --> 2', '1 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17506.883012681126 ['1 --> 0', '0 --> 2', '1 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17621.89518227616 ['1 --> 0', '0 --> 2', '1 --> 2', '3 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17573.385827431914 ['0 --> 2', '1 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17604.527149300975 ['1 --> 0', '0 --> 2', '3 --> 0', '1 --> 2', '3 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17625.22324487297 ['1 --> 0', '0 --> 2', '3 --> 0', '1 --> 2', '3 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17618.806486357407 ['1 --> 0', '0 --> 2', '3 --> 0', '1 --> 2', '3 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17560.30245577793 ['1 --> 0', '0 --> 2', '1 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17563.083579592167 ['1 --> 0', '0 --> 2', '1 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17561.40023952848 ['0 --> 2', '1 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17586.854533376554 ['0 --> 2', '1 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17540.085191496877 ['1 --> 0', '0 --> 2', '1 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17623.43614082811 ['1 --> 0', '0 --> 2', '3 --> 0', '1 --> 2', '3 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17514.656716115023 ['1 --> 0', '0 --> 2', '3 --> 0', '1 --> 2', '3 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17521.698403031925 ['1 --> 0', '0 --> 2', '3 --> 0', '1 --> 2', '3 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17557.085872642696 ['0 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17540.019134485312 ['1 --> 0', '0 --> 2', '3 --> 0', '1 --> 2', '3 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17472.269341729254 ['1 --> 0', '0 --> 2', '3 --> 0', '1 --> 2', '3 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17510.285760339073 ['1 --> 0', '0 --> 2', '1 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17567.469780482577 ['0 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17534.568210097317 ['0 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17533.589357928708 ['1 --> 0', '0 --> 2', '1 --> 2', '3 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17536.325074504995 ['1 --> 0', '0 --> 2', '3 --> 0', '1 --> 2', '3 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17624.651150011756 ['1 --> 0', '0 --> 2', '3 --> 0', '1 --> 2', '3 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17590.353804680686 ['1 --> 0', '0 --> 2', '1 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17689.770110731788 ['1 --> 0', '0 --> 2', '3 --> 0', '1 --> 2', '3 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17506.91669398028 ['0 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17530.542429835223 ['1 --> 0', '0 --> 2', '1 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17505.845006696618 ['1 --> 0', '0 --> 2', '3 --> 0', '1 --> 2', '3 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17538.049780926754 ['0 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17584.585878886322 ['1 --> 0', '0 --> 2', '1 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17499.482371658833 ['1 --> 0', '0 --> 2', '1 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17593.834525498634 ['1 --> 0', '0 --> 2', '3 --> 0', '1 --> 2', '3 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17533.19484450185 ['1 --> 0', '0 --> 2', '1 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17562.889194173666 ['1 --> 0', '0 --> 2', '3 --> 0', '1 --> 2', '3 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17555.09186746507 ['1 --> 0', '0 --> 2', '3 --> 0', '1 --> 2', '3 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17600.33431243173 ['1 --> 0', '0 --> 2', '3 --> 0', '1 --> 2', '3 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17595.70401456135 ['0 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17562.467855422976 ['0 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17588.22854042161 ['0 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17475.803280754793 ['0 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17630.83848942553 ['1 --> 0', '0 --> 2', '3 --> 0', '1 --> 2', '3 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17579.17063217328 ['1 --> 0', '0 --> 2', '3 --> 0', '1 --> 2', '3 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17524.418155932133 ['1 --> 0', '0 --> 2', '1 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17530.048201713475 ['1 --> 0', '0 --> 2', '3 --> 0', '1 --> 2', '3 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17513.037611014104 ['1 --> 0', '0 --> 2', '1 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17601.939541829146 ['1 --> 0', '0 --> 2', '1 --> 2', '3 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17601.14162754829 ['0 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17649.449722299407 ['1 --> 0', '0 --> 2', '3 --> 0', '1 --> 2', '3 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17573.468511006864 ['1 --> 0', '0 --> 2', '1 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17618.903958232026 ['0 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17558.96187339683 ['1 --> 0', '0 --> 2', '1 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17587.719661933326 ['0 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17544.94378475325 ['1 --> 0', '0 --> 2', '1 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17586.78541488831 ['0 --> 2', '3 --> 0']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17579.030091895303 ['1 --> 0', '0 --> 2', '3 --> 0', '1 --> 2', '3 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17544.22392556648 ['0 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17589.379833748062 ['0 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17584.08676660702 ['1 --> 0', '0 --> 2', '3 --> 0', '1 --> 2', '3 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17447.754495668996 ['1 --> 0', '0 --> 2', '3 --> 0', '1 --> 2', '3 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17573.39333385148 ['1 --> 0', '0 --> 2', '3 --> 0', '1 --> 2', '3 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17521.601604997344 ['1 --> 0', '0 --> 2', '3 --> 0', '1 --> 2', '3 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17540.91458376401 ['1 --> 0', '0 --> 2', '1 --> 2', '3 --> 2']
# Dropping [] Index(['0', '1', '3', '2'], dtype='object')
# Causal_df  Index(['0', '1', '3', '2'], dtype='object')
# -17519.152686265745 ['1 --> 0', '0 --> 2', '1 --> 2']
# [-17528.017295998765, -17594.789198580533, -17607.134879922596, -17603.276044031325, -17656.974444599644, -17474.252964329597, -17516.18397613654, -17704.95301000306, -17502.28031879528, -17551.558464464262, -17531.763836986847, -17543.484905360558, -17567.65096407388, -17587.253521576742, -17615.66298792793, -17662.637393960038, -17629.66958640447, -17507.41884170113, -17568.705748135526, -17573.61595161299, -17478.493304595682, -17617.002127746964, -17556.754335648944, -17553.268013848647, -17649.28218063217, -17530.20036384427, -17498.2042625761, -17594.89181597412, -17555.33741824989, -17613.287997451407, -17601.880779320556, -17535.208150930386, -17570.78339338678, -17539.379628092953, -17548.858769169878, -17601.272913418914, -17564.76717989891, -17506.883012681126, -17621.89518227616, -17573.385827431914, -17604.527149300975, -17625.22324487297, -17618.806486357407, -17560.30245577793, -17563.083579592167, -17561.40023952848, -17586.854533376554, -17540.085191496877, -17623.43614082811, -17514.656716115023, -17521.698403031925, -17557.085872642696, -17540.019134485312, -17472.269341729254, -17510.285760339073, -17567.469780482577, -17534.568210097317, -17533.589357928708, -17536.325074504995, -17624.651150011756, -17590.353804680686, -17689.770110731788, -17506.91669398028, -17530.542429835223, -17505.845006696618, -17538.049780926754, -17584.585878886322, -17499.482371658833, -17593.834525498634, -17533.19484450185, -17562.889194173666, -17555.09186746507, -17600.33431243173, -17595.70401456135, -17562.467855422976, -17588.22854042161, -17475.803280754793, -17630.83848942553, -17579.17063217328, -17524.418155932133, -17530.048201713475, -17513.037611014104, -17601.939541829146, -17601.14162754829, -17649.449722299407, -17573.468511006864, -17618.903958232026, -17558.96187339683, -17587.719661933326, -17544.94378475325, -17586.78541488831, -17579.030091895303, -17544.22392556648, -17589.379833748062, -17584.08676660702, -17447.754495668996, -17573.39333385148, -17521.601604997344, -17540.91458376401, -17519.152686265745]
# MSE =  18.42345121079045
# BIC =  18.29948020883954
# COMB =  18.37046682588286
# Times =  1
# [2, 3] [2.0, 3.0]
# A =  {('0', '2'), ('0', '1'), ('3', '1'), ('3', '0'), ('3', '2'), ('1', '2')}
# B =  {('0', '2'), ('0', '1'), ('3', '1'), ('3', '0'), ('1', '2')}
# A =  {('0', '2'), ('0', '3'), ('1', '3'), ('1', '0'), ('3', '2'), ('1', '2')}
# B =  {('0', '2'), ('0', '3'), ('1', '3'), ('1', '0'), ('3', '2')}
# A =  {('0', '2'), ('0', '1'), ('0', '3'), ('3', '1'), ('3', '2')}
# B =  {('0', '2'), ('0', '3'), ('0', '1'), ('3', '1'), ('3', '2')}
# Inputs =  ['1', '2', '3']
# Target =  ['0']
# Descendents =  {1, 2, 3}
# Removing descendants
# Required before [['0', '3'], ['0', '2'], ['0', '1'], ['3', '1'], ['3', '2']]
# Removing ['0', '1']
# Removing ['3', '1']
# Removing ['0', '2']
# Removing ['3', '2']
# Removing ['0', '3']
# Required After: []
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-a7306d1d0e79> in <module>()
#     102             model.compile(optimizer = optimizers.SGD(lr = 0.0001, momentum = 0.9, ), loss='mean_squared_error', metrics = ['mse'])
#     103             #print(len(X), len(y))
# --> 104             model.fit(x_train, y_train, epochs = 20, validation_data = (x_val, y_val), callbacks = callbacks, batch_size = 32, verbose = verbosity)
#     105         else:
#     106             models[idx].fit(X,y)
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# ~/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# ~/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args)
#    1449         if self._session._created_with_new_api:
#    1450           return tf_session.TF_SessionRunCallable(
# -> 1451               self._session._session, self._handle, args, status, None)
#    1452         else:
#    1453           return tf_session.TF_DeprecatedSessionRunCallable(
#
# KeyboardInterrupt:

# %%
def get_bic(df, prior, penalty = 2):

    tetrad.run(algoId = 'gfci', dfs = df, testId= 'sem-bic', scoreId = 'sem-bic', dataType = 'continuous',
               structurePrior = 1.0, samplePrior = 1, maxDegree = -1, maxPathLength = -1, priorKnowledge = prior,
               completeRuleSetUsed = False, faithfulnessAssumed = True, verbose = True, penalty = 200
               )
    
    BIC = tetrad.getTetradGraph().getAllAttributes().toString()
    BIC = float(BIC.split('=')[-1].split('}')[0])
    return BIC #/ len(df)

get_bic(causal_df, prior)
tetrad.getEdges()
tetrad.getTetradGraph().getAllAttributes().toString()
# Out:
# '{BIC=24479.609410385827}'

# %%
prior
# Out:
# Instance of edu.cmu.tetrad.data.Knowledge2: /knowledge
# addtemporal
#
#
# forbiddirect
#
# requiredirect

# %%
def get_average_improvement(df1, df2):
    ret = []
    for i, j in zip(df1,df2):
        ret.append(np.sum(j) - np.sum(i))
    return ret

improvement = get_average_improvement(bestMSE, bestCOMBO)
np.mean(improvement), np.std(improvement)


fig, ax = plt.subplots()
ax.plot(averageDegree,improvement, '.')
plt.show()


fig, ax = plt.subplots()
ax.plot(targetDegree,improvement, '.')
plt.show()


fig, ax = plt.subplots()
ax.plot(target_inD,improvement, '.')
plt.show()

fig, ax = plt.subplots()
ax.plot(target_outD,improvement, '.')
plt.show()

fig, ax = plt.subplots()
ax.plot(descendants,improvement, '.')
plt.show()

# %%
def box_plots(X,Y):
    box = []
    for i in np.unique(X):
        box.append([])
    for x,y in zip(X, Y):
        box[x].append(y)
    fig = plt.figure()

    ax = fig.add_subplot(111)
    ax.yaxis.grid(True)
    ax.set_xlabel("Number of Target Descendants")
    ax.set_ylabel("L1 Loss Improvement")
    bp = ax.boxplot(box, showfliers=False, labels = ['0', '1', '2', '3'])
    
box_plots(descendants, improvement)
box_plots(target_outD, improvement)
box_plots(target_inD, improvement)

# %%
improvement
# Out:
# [-0.0006374884583220108,
#  -0.006563246319611693,
#  -0.08639814275495183,
#  -0.012051385986666219,
#  -0.11623136253577826,
#  -0.06894619367183097,
#  -0.005687500426425629,
#  0.011421395275242219,
#  -0.030980521111590775,
#  -0.07769497735489495,
#  -0.013953467757497506,
#  -0.07182149830688545,
#  -0.06750572657882614,
#  -0.11798691961421426,
#  0.00014111544140860133,
#  -0.09454733546234095,
#  -0.025946347490421573,
#  0.038575160630568206,
#  -0.11114299829187502,
#  -0.004607830961333548,
#  -0.06861635263062027,
#  -0.03964305062158857,
#  -0.014393199871918227,
#  0.003043837285744644,
#  0.00018810081359710296,
#  0.06084163368302242,
#  -0.12353300626129382,
#  -0.005139306002881483,
#  -0.0223672457858477,
#  -0.004822748445935332,
#  -0.014111734162607803,
#  0.005979404410169309,
#  -0.00447140468689966,
#  -0.009402449231135535,
#  -0.011772320188164542,
#  -0.018237038592005206]

# %%
np.mean(bestMSE), np.mean(bestCOMBO), np.std(bestMSE), np.std(bestCOMBO), np.mean(averageDegree),np.std(averageDegree), np.mean(targetDegree), np.std(targetDegree)
# Out:
# (1.4445040749237175,
#  1.4423262172517248,
#  0.35756226510125927,
#  0.35495020909793984,
#  2.735294117647059,
#  0.4575396819442366,
#  2.764705882352941,
#  0.42418250299576343)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-05dc37c61656> in <module>()
# ----> 1 G.get_edge_data(target)
#
# TypeError: get_edge_data() missing 1 required positional argument: 'v'

# %%
improvement
fig, ax = plt.subplots()
ax.plot(averageDegree,improvement, '.')
plt.show()

improvement
fig, ax = plt.subplots()
ax.plot(targetDegree,improvement, '.')
plt.show()


improvement
fig, ax = plt.subplots()
ax.plot(target_inD,improvement, '.')
plt.show()

improvement
fig, ax = plt.subplots()
ax.plot(target_outD,improvement, '.')
plt.show()

# %%
fig, ax = plt.subplots()
b,m = polyfit(proposed,generalization, 1)
text(0.05, 0.9,'Pearson coeff:' + str(pearsonr(proposed,generalization)[0])[0:4], ha='left', va='center', transform=ax.transAxes)
ax.plot(proposed,generalization, '.')
plt.plot(proposed, b + m * np.array(proposed), '-')
ax.set_xlabel("BIC")
ax.set_ylabel("GEN")
fig.savefig('Ex4MSEVsAUS.pdf', bbox_inches='tight')
plt.show()

fig, ax = plt.subplots()
b,m = polyfit(metrics,generalization, 1)
text(0.05, 0.9,'Pearson coeff:' + str(pearsonr(metrics,generalization)[0])[0:4], ha='left', va='center', transform=ax.transAxes)
ax.plot(metrics,generalization, '.')
plt.plot(metrics, b + m * np.array(metrics), '-')
ax.set_xlabel("MSE")
ax.set_ylabel("GEN")
fig.savefig('Ex4MSEVsAUS.pdf', bbox_inches='tight')
plt.show()


total = normalize(metrics) + normalize(proposed)
fig, ax = plt.subplots()
b,m = polyfit(total,generalization, 1)
text(0.05, 0.9,'Pearson coeff:' + str(pearsonr(total,generalization)[0])[0:4], ha='left', va='center', transform=ax.transAxes)
ax.plot(total,generalization, '.')
plt.plot(total, b + m * np.array(total), '-')
ax.set_xlabel("MSE")
ax.set_ylabel("GEN")
fig.savefig('Ex4MSEVsAUS.pdf', bbox_inches='tight')
plt.show()

# %%
nbest = 10
final = pd.DataFrame(np.stack((metrics, proposed, total, generalization), axis = 1), columns = ['metrics', 'proposed', 'combined', 'generalization'])
print("MSE = ", np.sum(final.nsmallest(nbest, 'metrics')['generalization']))
print("BIC = ", np.sum(final.nsmallest(nbest, 'proposed')['generalization']))
print("COMB = ",np.sum(final.nsmallest(nbest, 'combined')['generalization']))
